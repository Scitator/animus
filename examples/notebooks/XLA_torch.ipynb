# %%
! pip install cloud-tpu-client==0.10 https://storage.googleapis.com/tpu-pytorch/wheels/torch_xla-1.9-cp37-cp37m-linux_x86_64.whl
! pip install torch==1.9.0+cu111 torchvision==0.10.0+cu111 -f https://download.pytorch.org/whl/cu111/torch_stable.html

# %%
! export GIT_REPO="scitator/animus" && git clone https://github.com/${GIT_REPO}
! export BRANCH="main" && cd animus && git checkout -b $BRANCH origin/$BRANCH  && git pull origin $BRANCH
! pip install -r ./animus/requirements/requirements_torch_dl.txt

# %%
from torch import __version__

print(__version__)
# Out:
# 1.9.0+cu102

# %% [markdown]
# # Tests

# %%
! cd animus && OMP_NUM_THREADS="1" MKL_NUM_THREADS="1" PYTHONPATH="." python examples/torch_dl/torch_run.py --engine="xla"
